# %%
# building the CNN

# %%
from keras.models import Sequential
# Out:
# Using Theano backend.
# Can not use cuDNN on context None: cannot compile with cuDNN. We got this error:
# b'C:\\Users\\JITHUR~1\\AppData\\Local\\Temp\\try_flags_sas0njyl.c:4:10: fatal error: cudnn.h: No such file or directory\r\n #include <cudnn.h>\r\n          ^~~~~~~~~\r\ncompilation terminated.\r\n'
# Mapped name None to device cuda: GeForce 610M (0000:01:00.0)

# %%
from keras.layers import Convolution2D

# %%
from keras.layers import MaxPooling2D

# %%
from keras.layers import Flatten

# %%
from keras.layers import Dense

# %%
#initializing CNN

# %%
classifier = Sequential()

# %%
# add convolution layer

# %%
# for tf backend
classifier.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
# Out:
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '2872' (I am process '15208')

# %%
# add pooling layer

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
# flattening

# %%
classifier.add(Flatten())

# %%
# adding fully connected layer

# %%
classifier.add(Dense(output_dim=128,activation='relu'))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
#   if __name__ == '__main__':

# %%
classifier.add(Dense(output_dim=1,activation='sigmoid'))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`
#   if __name__ == '__main__':

# %%
# compiling the CNN

# %%
classifier.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# fitting the data

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
        '../instructor/dataset/training_set',
        target_size=(64,64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
        '../instructor/dataset/test_set',
        target_size=(64,64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
classifier.fit_generator(
        training_set,
        steps_per_epoch=8000,
        epochs=25,
        validation_data=test_set,
        validation_steps=2000)
# Out:
# Epoch 1/25
# 5055/8000 [=================>............] - ETA: 1284s - loss: 0.4738 - acc: 0.7678
